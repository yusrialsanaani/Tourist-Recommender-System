# %%
# !pip3 install beautifulsoup4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
r = requests.get('https://www.tripadvisor.in/Attractions-g153339-Activities-a_allAttractions.true-Canada.html')
content = r.content
soup = BeautifulSoup(content)
#print(soup)

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
r1 = requests.get('https://www.tripadvisor.in/Attractions-g153339-Activities-oa30-Canada.html')
content1 = r1.content
soup1 = BeautifulSoup(content1)
#print(soup)

# %%
 alls = []
 for d in soup.findAll('div', attrs={'class':'_392swiRT'}):
   #print(d)
   location_name = d.find('div', attrs={'class':'_35oYbnyI'})
   n = location_name.get_text()
   #print(n)
   rating = d.find('svg', attrs={'class':'zWXXYhVR'})
   r=rating.get('title')
   #star=rating.get_text()
   users_rated = d.find('span', attrs={'class':'DrjyGw-P _26S7gyB4 _14_buatE _1dimhEoy'})
  
   #location=d.find('a',attrs={'class':'_3s_5RiH-'})
   #loc=location.get('href')
   typeloc=d.find('div',attrs={'class':'DrjyGw-P _26S7gyB4 _3SccQt-T'})
  



   all1=[]

   if location_name is not None:
     all1.append(n)
   else:
       all1.append("unknown-product")

   if typeloc is not None:
      all1.append(typeloc.text)   
       
   if rating is not None:
      all1.append(r[0:4])
   else:
        all1.append('-1')
   if users_rated is not None:
      all1.append(users_rated.text)
   else:
       all1.append('0')
   #if location is not None:
     #.append(loc[-40:-5])
   alls.append(all1)

# %%
 alls1 = []
 for d in soup1.findAll('div', attrs={'class':'_392swiRT'}):
   #print(d)
   location_name = d.find('div', attrs={'class':'_35oYbnyI'})
   n = location_name.get_text()
   #print(n)
   rating = d.find('svg', attrs={'class':'zWXXYhVR'})
   r=rating.get('title')
   #star=rating.get_text()
   users_rated = d.find('span', attrs={'class':'DrjyGw-P _26S7gyB4 _14_buatE _1dimhEoy'})
  
   #location=d.find('a',attrs={'class':'_3s_5RiH-'})
   #loc=location.get('href')
   typeloc=d.find('div',attrs={'class':'DrjyGw-P _26S7gyB4 _3SccQt-T'})


   all1=[]

   if location_name is not None:
     all1.append(n)
   else:
       all1.append("unknown-product")

   if typeloc is not None:
      all1.append(typeloc.text)   
       
   if rating is not None:
      all1.append(r[0:4])
   else:
        all1.append('-1')
   if users_rated is not None:
      all1.append(users_rated.text)
   else:
       all1.append('0')
   #if location is not None:
     #.append(loc[-40:-5])
   alls1.append(all1)

# %%
all=alls+alls1

# %%
df_1=pd.DataFrame(all,columns=['location_name','location_type','ratings','no. of rating'])
df_1['location_type']=df_1['location_type'].str.replace('•',' ')
pattern = r'[0-9]'
df_1['location_name']=df_1['location_name'].apply(lambda x: re.sub(pattern,' ',x))
df_1['location_name']=df_1['location_name'].str.replace('.',' ')
df_1
# Out:
#                              location_name  ... no. of rating
# 0              Ripley's Aquarium of Canada  ...        20,326
# 1                         Mount Royal Park  ...        10,493
# 2                             Stanley Park  ...        28,722
# 3                     Niagara Falls Canada  ...        31,477
# 4                               Old Quebec  ...        13,360
# 5         Heritage Park Historical Village  ...         3,133
# 6            Parliament Hill and Buildings  ...         9,512
# 7                          Royal BC Museum  ...         7,034
# 8                            Banff Gondola  ...        10,202
# 9                      Toronto Island Park  ...         8,437
# 10                            Lake Ontario  ...           790
# 11                      West Edmonton Mall  ...         4,198
# 12                   Peller Estates Winery  ...         2,790
# 13                      Whistler Blackcomb  ...         4,229
# ...

# %%
df2=['ontario','quebec','BC','ontario','quebec','alberta','ontario','BC','alberta','ontario','ontario','alberta','ontario','BC','manitoba','nova scotia','BC','ontario','BC','alberta','ontario','quebec','quebec','quebec','BC','BC','ontario','ontario','alberta','ontario','ontario','alberta','alberta','alberta','new foundland','alberta','BC','ontario','ontario','ontario','alberta','BC','ontario','BC','alberta','nova scotia','alberta','BC','ontario','BC','ontario','BC','quebec','alberta','quebec','edward island','ontario','Saskatchewan','BC','nova scotia']
df_2=pd.DataFrame(df2,columns=['provience'])
df_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-215be305d904> in <module>()
#       1 df2=['ontario','quebec','BC','ontario','quebec','alberta','ontario','BC','alberta','ontario','ontario','alberta','ontario','BC','manitoba','nova scotia','BC','ontario','BC','alberta','ontario','quebec','quebec','quebec','BC','BC','ontario','ontario','alberta','ontario','ontario','alberta','alberta','alberta','new foundland','alberta','BC','ontario','ontario','ontario','alberta','BC','ontario','BC','alberta','nova scotia','alb...
# ----> 2 df_2=pd.DataFrame(df2,columns=['provience'])
#       3 df_2
#
# NameError: name 'pd' is not defined

# %%
best_time_visit=['summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time','summer','fall','all time','all time']

# %%
cost_userid=[['15$','1'],['5$','2'],['free','3'],['free','4'],['10$','5'],['free','6'],['free','7'],['5$','1'],['free','9'],['20$','12'],
             ['5$','11'],['50$','10'],['free','7'],['free','5'],['6$','2'],['free','1'],['35$','1'],['50$','8'],['free','3'],['free','10'],
             ['15$','8'],['5$','12'],['free','3'],['free','4'],['10$','7'],['free','2'],['11$','2'],['5$','4'],['free','9'],['free','12'],
             ['15$','10'],['15$','5'],['5$','6'],['free','10'],['10$','5'],['free','6'],['15$','7'],['5$','1'],['free','5'],['20$','10'],
             ['free','11'],['5$','7'],['free','12'],['free','1'],['10$','5'],['free','6'],['15$','10'],['5$','3'],['free','9'],['20$','11'],
             ['free','8'],['12$','4'],['2$','1'],['free','4'],['10$','5'],['free','6'],['15$','7'],['5$','1'],['free','9'],['free','12']
             ]

# %%
df_5=pd.DataFrame(cost_userid,columns=['cost','user_id'])
df_5
# Out:
#     cost user_id
# 0    15$       1
# 1     5$       2
# 2   free       3
# 3   free       4
# 4    10$       5
# 5   free       6
# 6   free       7
# 7     5$       1
# 8   free       9
# 9    20$      12
# 10    5$      11
# 11   50$      10
# 12  free       7
# 13  free       5
# 14    6$       2
# 15  free       1
# 16   35$       1
# 17   50$       8
# 18  free       3
# 19  free      10
# 20   15$       8
# 21    5$      12
# 22  free       3
# 23  free       4
# 24   10$       7
# 25  free       2
# 26   11$       2
# 27    5$       4
# 28  free       9
# 29  free      12
# 30   15$      10
# 31   15$       5
# 32    5$       6
# 33  free      10
# 34   10$       5
# 35  free       6
# 36   15$       7
# 37    5$       1
# 38  free       5
# 39   20$      10
# 40  free      11
# 41    5$       7
# 42  free      12
# 43  free       1
# 44   10$       5
# 45  free       6
# 46   15$      10
# 47    5$       3
# 48  free       9
# 49   20$      11
# 50  free       8
# ...

# %%
df_3=pd.DataFrame(best_time_visit,columns=['best time to visit'])
df_3
# Out:
#    best time to visit
# 0              summer
# 1                fall
# 2            all time
# 3            all time
# 4              summer
# 5                fall
# 6            all time
# 7            all time
# 8              summer
# 9                fall
# 10           all time
# 11           all time
# 12             summer
# 13               fall
# 14           all time
# 15           all time
# 16             summer
# 17               fall
# 18           all time
# 19           all time
# 20             summer
# 21               fall
# 22           all time
# 23           all time
# 24             summer
# 25               fall
# 26           all time
# 27           all time
# 28             summer
# 29               fall
# 30           all time
# 31           all time
# 32             summer
# 33               fall
# 34           all time
# 35           all time
# 36             summer
# 37               fall
# 38           all time
# 39           all time
# ...

# %%
open_close_timming=[['Sun - Sat 10:00 AM - 8:00 PM','288 Bremner Boulevard, Toronto, Ontario M5V 3L9 Canada','http://www.ripleyaquariums.com/canada','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/07/f0/d6/1e/ripley-s-aquarium-of.jpg?w=400&h=400&s=1'],
                    ['Sun - Sat 6:00 AM - 12:00 AM','1260 Remembrance Road, Montreal, Quebec H3H 1A2 Canada','http://www.lemontroyal.qc.ca/en','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/11/19/02/fe/photo1jpg.jpg?w=400&h=400&s=1'],
                    ['Sun-Sat 8:00 AM- 6:00 PM','Stanley Park Causeway, Vancouver, British Columbia V6G 1Z4 Canada','http://vancouver.ca/parks-recreation-culture/stanley-park.aspx','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/10/a6/09/9f/beautiful-view-of-stanley.jpg?w=400&h=400&s=1'],
                    ['Thu - Thu 12:00 AM - 11:59 PM','Niagara Falls, Ontario L2G 3Y9 Canada','https://www.niagarafallstourism.com/','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0d/a3/8b/5f/niagara-falls.jpg?w=400&h=400&s=1'],
                    ['Sun - Sat 10:00 AM - 8:00 PM','Rue de Tresor, Quebec City, Quebec GIR 5B8 Canada','http://whc.unesco.org/en/list/300','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/15/64/49/7b/photos-were-taken-on.jpg?w=400&h=-1&s=1'],
                    ['Sun - Sat 6:00 AM - 12:00 AM','1900 Heritage Dr SW, Calgary, Alberta T2V 2X3 Canada','http://www.heritagepark.ca/','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0b/79/69/37/heritage-park-historical.jpg?w=400&h=400&s=1'],
                    ['Sun - Sat 12:00PM - 12:00 AM','111 Wellington St, Ottawa, Ontario K1A 0A6 Canada','http://www.parl.gc.ca/visitors/index-e.asp','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/16/c3/61/60/east-block.jpg?w=400&h=400&s=1'],
                    ['Sat - Tue 10:00 AM - 6:00 PM','675 Belleville St, Victoria, British Columbia V8W 1A1 Canada','http://www.royalbcmuseum.bc.ca/','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0b/4c/b2/0e/royal-bc-museum.jpg?w=400&h=400&s=1'],
                    ['Mon - Sun 11:00 AM - 9:00 PM','Mountain Avenue, Banff, Banff National Park, Alberta T1L 1B2 Canada','http://www.banffgondola.com/','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/1c/44/d2/4f/owned-by-pursuit.jpg?w=400&h=400&s=1'],
                    ['Sun - Sat 10:00 AM - 5:00 PM','9 Queens Quay West Bay Street, Jack Layton Ferry Terminal, Toronto, Ontario M5J 2H3 Canada','http://www.toronto.ca/parks/island/','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0d/9f/cb/a0/toronto-island-parks.jpg?w=400&h=400&s=1'],
                    ['Sun - Sat
','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/08/bb/57/4a/brandywine-falls-provincial.jpg?w=400&h=400&s=1'],
                    ['Fri - Sun 10:00 AM - 4:00 PM','100 Laurier St, Gatineau, Quebec K1A 0M8 Canada','http://www.historymuseum.ca/','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0e/c5/31/27/grand-hall.jpg?w=400&h=400&s=1'],
                    ['Sat - Wed 10:00 AM - 6:00 PM','Icefield Parkway, Lake Louise, Banff National Park, Alberta Canada','http://banffandbeyond.com/category/banff-lake-louise/peyto-lake-and-bow-summit','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/02/2a/ab/fc/peyto-lake.jpg?w=400&h=400&s=1'],
                    ['Sun - Sat 12:00 AM - 11:59 PM','1000 chemin des Voyageurs, Mont Tremblant, Quebec J8E 1T1 Canada','http://www.tremblant.ca/','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0e/13/75/94/fall-colors.jpg?w=400&h=400&s=1'],
                    ['Fri - Sun 10:00 AM - 4:00 PM','Prince Edward Island Canada','http://www.pc.gc.ca/pn-np/pe/pei-ipe/visit.aspx','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0b/ed/bd/60/one-of-the-many-stunning.jpg?w=400&h=400&s=1'],
                    ['Sat - Wed 10:00 AM - 6:00 PM','Tobermory, Ontario N0H 2R0 Canada','http://www.pc.gc.ca/en/amnc-nmca/on/fathomfive/activ/flowerpot','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/07/ef/16/df/flowerpot-island.jpg?w=400&h=400&s=1'],
                    ['Sun - Sat 12:00 AM - 11:59 PM','2610 Lorne Ave, Saskatoon, Saskatchewan S7J 0S6 Canada','http://www.wdm.ca/stoon.html','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0e/a3/02/a0/a-great-place-to-visit.jpg?w=400&h=400&s=1'],
                    ['Fri - Sun 10:00 AM - 4:00 PM','Morningside Drive, Nanaimo, British Columbia Canada','http://www.nanaimo.ca/PRC/Locations/Parks/224-Neck-Point-Park','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/04/78/96/30/the-lookout.jpg?w=400&h=400&s=1'],
                    ['Sat - Wed 10:00 AM - 6:00 PM','Nova Scotia,canada','-','https://dynamic-media-cdn.tripadvisor.com/media/photo-o/01/08/3a/bb/part-of-the-valley-from.jpg?w=400&h=400&s=1'],
                    ]

# %%
df_4=pd.DataFrame(open_close_timming,columns=['visiting_hours','Address','Website_link','image_link'])
df_4
# Out:
#                    visiting_hours  ...                                         image_link
# 0    Sun - Sat 10:00 AM - 8:00 PM  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 1    Sun - Sat 6:00 AM - 12:00 AM  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2        Sun-Sat 8:00 AM- 6:00 PM  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3   Thu - Thu 12:00 AM - 11:59 PM  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    Sun - Sat 10:00 AM - 8:00 PM  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 5    Sun - Sat 6:00 AM - 12:00 AM  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 6    Sun - Sat 12:00PM - 12:00 AM  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 7    Sat - Tue 10:00 AM - 6:00 PM  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 8    Mon - Sun 11:00 AM - 9:00 PM  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# ...

# %%
merge_df=df_1.join(df_2).join(df_5).join(df_3).join(df_4)
merge_df
# Out:
#                              location_name  ...                                         image_link
# 0              Ripley's Aquarium of Canada  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 1                         Mount Royal Park  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2                             Stanley Park  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                     Niagara Falls Canada  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4                               Old Quebec  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 5         Heritage Park Historical Village  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 6            Parliament Hill and Buildings  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# 7                          Royal BC Museum  ...  https://dynamic-media-cdn.tripadvisor.com/medi...
# ...

# %%
from google.colab import files
import csv
merge_df.to_csv('attraction_info_df_final_1.csv') 
files.download('attraction_info_df_final_1.csv')
